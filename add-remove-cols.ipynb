# %%
import pandas as pd
bios = pd.read_csv("./data/bios.csv")
coffee = pd.read_csv("./data/coffee.csv")

# %%
bios.drop(columns=["died_date", "NOC"])

# %%
import numpy as np
coffee["Price"] = np.where(coffee["Coffee Type"] == "Espresso", 10, 7)

# %%
coffee["Revenue"] = coffee["Units Sold"] * coffee["Price"]
coffee

# %%
coffee = coffee.rename(columns={'New_Price': 'Price'})
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso          25     10      250
# 1      Monday       Latte          15      7      105
# 2     Tuesday    Espresso          30     10      300
# 3     Tuesday       Latte          20      7      140
# 4   Wednesday    Espresso          35     10      350
# 5   Wednesday       Latte          25      7      175
# 6    Thursday    Espresso          40     10      400
# 7    Thursday       Latte          30      7      210
# 8      Friday    Espresso          45     10      450
# 9      Friday       Latte          35      7      245
# 10   Saturday    Espresso          45     10      450
# 11   Saturday       Latte          35      7      245
# 12     Sunday    Espresso          45     10      450
# 13     Sunday       Latte          35      7      245
